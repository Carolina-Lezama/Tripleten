# %% [markdown]
# # ¡Hola Carolina! 😊
#
# Mi nombre es **Alejandro Castellanos** y hoy tengo el placer de ser el revisor de tu proyecto.
#
# Voy a revisar todo tu código con detalle, buscando tanto los puntos fuertes como aquellos en los que podrías mejorar. Te dejaré comentarios a lo largo del notebook, destacando lo que has hecho bien y sugiriendo ajustes donde sea necesario. Si encuentro algún error, no te preocupes, te lo haré saber de forma clara y te daré información útil para que puedas corregirlo en la próxima iteración. Si en algún punto tienes comentarios, siéntete libre de dejarlos también.
#
#
# Encontrarás mis comentarios específicos dentro de cajas verdes, amarillas o rojas, es muy importante que no muevas, modifiques o borres mis comentarios, con el fin de tener un seguimiento adecuado de tu proceso:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>
#
# A continuación te dejaré un comentario general con mi valoración del proyecto. **¡Mi objetivo es que sigas aprendiendo y mejorando con cada paso!**

# %% [markdown]
# -----

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario General del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Carolina completaste todas las tareas propuestas para el proyecto de manera sobresaliente. Demostraste un excelente manejo de las herramientas de visualización de datos y un buen dominio en la prueba de hipótesis, lo cual fortalece el análisis de los datos con los que has trabajado. Continúa desarrollando estas habilidades, ya que serán claves en futuros proyectos.
#
# Éxitos en tu próximo sprint 🚀
#
# *Estado del Proyecto:* **Aprobado**
#
# </div>

# %% [markdown]
# ------

# %% [markdown]
# ##hola

# %%
#importar librerias
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats as st

# %%
#importar dataframes
df_1_sql = pd.read_csv('/datasets/project_sql_result_01.csv')
#company_name: nombre de la empresa de taxis
#trips_amount: el número de viajes de cada compañía de taxis el 15 y 16 de noviembre de 2017.

df_4_sql = pd.read_csv('/datasets/project_sql_result_04.csv') 
#dropoff_location_name: barrios de Chicago donde finalizaron los viajes
#average_trips: el promedio de viajes que terminaron en cada barrio en noviembre de 2017.

# %%
#revisar los datos que contienen
df_1_sql.info()
print()
print(df_1_sql.sample(5))

print('-' *30 )

df_4_sql.info()
print()
print(df_4_sql.sample(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_name  64 non-null     object
#  1   trips_amount  64 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB
#
#                    company_name  trips_amount
# 26              Gold Coast Taxi           428
# 40  6574 - Babylon Express Inc.            31
# 55    6057 - 24657 Richard Addo            13
# 6                  City Service          8448
# 49       5074 - 54002 Ahzmi Inc            16
# ------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dropoff_location_name  94 non-null     object
#  1   average_trips          94 non-null     float64
# ...

# %% [markdown]
# Veamos a detalle que pasa aqui:
#
# dataframe 1:
# tiene solo 64 filas, de las cuales ninguna tiene nulos, contiene solo 2 columnas y son adecuadas al tipo de dato que muestran en el sample, pero se debe verificar a profundidad los valores de object, quiza no haya nulos pero puede haber valores que lo reemplacen.
#
# dataframe 2:
# tiene 94 filas, no hay datos nulos, son 2 columnas de las cuales son adecuadas a sus tipos, requiere mas observacion en los valores de object y posiblemente reducir los decimales en la segunda columna

# %%
#estudiar los datos que contienen
#dataframe 1

print(df_1_sql.duplicated().sum()) #contar valores duplicados
print()

print(df_1_sql['company_name'].unique()) #diferentes valores unicos
print(df_1_sql['company_name'].nunique()) 
print()

print(df_1_sql['company_name'].value_counts(dropna=False)) 
print()


#dataframe 2
df_4_sql['average_trips'] = df_4_sql['average_trips'].round(3) #redondear los decimales

print(df_4_sql.duplicated().sum()) 
print()

print(df_4_sql['dropoff_location_name'].unique()) 
print(df_4_sql['dropoff_location_name'].nunique()) 
print()

print(df_4_sql['dropoff_location_name'].value_counts(dropna=False)) 
print()
# Out:
# 0
#
# ['Flash Cab' 'Taxi Affiliation Services' 'Medallion Leasing' 'Yellow Cab'
#  'Taxi Affiliation Service Yellow' 'Chicago Carriage Cab Corp'
#  'City Service' 'Sun Taxi' 'Star North Management LLC'
#  'Blue Ribbon Taxi Association Inc.' 'Choice Taxi Association'
#  'Globe Taxi' 'Dispatch Taxi Affiliation' 'Nova Taxi Affiliation Llc'
#  'Patriot Taxi Dba Peace Taxi Association' 'Checker Taxi Affiliation'
#  'Blue Diamond' 'Chicago Medallion Management' '24 Seven Taxi'
#  'Chicago Medallion Leasing INC' 'Checker Taxi' 'American United'
#  'Chicago Independents' 'KOAM Taxi Association' 'Chicago Taxicab'
#  'Top Cab Affiliation' 'Gold Coast Taxi' 'Service Taxi Association'
#  '5 Star Taxi' '303 Taxi' 'Setare Inc' 'American United Taxi Affiliation'
#  'Leonard Cab Co' 'Metro Jet Taxi A' 'Norshore Cab'
#  '6742 - 83735 Tasha Ride Inc' '3591 - 63480 Chuks Cab'
#  '1469 - 64126 Omar Jada' '6743 - 78771 Luhak Corp'
#  '0118 - 42111 Godfrey S. Awir' '6574 - Babylon Express Inc.'
# ...

# %% [markdown]
# Resumen de la revision:
#
# dataframe 1:podemos ver claramente que no hay ningun valor repetido, todos son diferentes y unicos, cada uno se muestra solo una vez, no pude visualizar ningun valor que significara algo nulo o desconocido
#
# dataframe 2:podemos ver claramente que no hay ningun valor repetido, todos son diferentes y unicos, cada uno se muestra solo una vez, no pude visualizar ningun valor que significara algo nulo o desconocido, aqui tambien acorte los decimales a 3 para mas legibilidad.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Muy buen trabajo importando las librerías y los datos del proyecto. Adicionalmente usaste correctamente las funciones `info` y `sample`, esto te permite hacer una primera revisión de los datos, su estructura y contenido.
#
# Además hiciste un buen trabajo comprobando la presencia de datos duplicados, esto es clave para verificar la integridad del dataset y evitar sesgos o errores al momento de analizar los datos
#
#
# </div>

# %%
# identificar los 10 principales barrios en términos de finalización del recorrido
diez_principales = df_4_sql.sort_values(by='average_trips',ascending=False).head(10)
print(diez_principales)
# Out:
#   dropoff_location_name  average_trips
# 0                  Loop      10727.467
# 1           River North       9523.667
# 2         Streeterville       6664.667
# 3             West Loop       5163.667
# 4                O'Hare       2546.900
# 5             Lake View       2420.967
# 6            Grant Park       2068.533
# 7         Museum Campus       1510.000
# 8            Gold Coast       1364.233
# 9    Sheffield & DePaul       1259.767

# %%
#grafico para empresas de taxis y número de viajes

#ver que valores hay en trips_amount, esto para saber si graficar todos los valores o solo unos
print(df_1_sql['trips_amount'].value_counts(dropna=False).sort_index(ascending=False))

# Obtener las empresas de taxi con mas de 500
top_empresas = df_1_sql[df_1_sql['trips_amount'] > 500].sort_values(by='trips_amount', ascending=False)

# cantidad de empresas
print(len(top_empresas))

# Crear gráfico de barras horizontales
plt.figure(figsize=(10, 8))
plt.barh(top_empresas['company_name'], top_empresas['trips_amount'],color='skyblue')
plt.gca().grid(True, alpha=0.5) 
plt.xlabel('Número de viajes')
plt.ylabel('Empresa de taxis')
plt.title('Empresas de taxis con mas de 500 números de viajes')
plt.tight_layout()
plt.show()
# Out:
# 19558    1
# 11422    1
# 10367    1
# 9888     1
# 9299     1
# 9181     1
# 8448     1
# 7701     1
# 7455     1
# 5953     1
# 5015     1
# 4383     1
# 3355     1
# 3175     1
# 2235     1
# 2216     1
# 2070     1
# 1955     1
# 1775     1
# 1607     1
# 1486     1
# 1404     1
# 1296     1
# 1259     1
# 1014     1
# 978      1
# 428      1
# 402      1
# 310      1
# 250      1
# 230      1
# 210      1
# 147      1
# 146      1
# 127      1
# 39       1
# 37       1
# 36       1
# 33       2
# 31       1
# 29       3
# 27       1
# 25       1
# 21       2
# 20       1
# 16       1
# 15       2
# 14       3
# 13       1
# 12       1
# 11       1
# 8        1
# 7        2
# 5        1
# 3        1
# 2        1
# Name: trips_amount, dtype: int64
# 26

# %% [markdown]
# conclusiones y resultados:
# primero se realizo un ordenado de datos para ver las cantidades, al ser un dataframe pequeño fue posible esto, pudimos ver que los valores realmente son muy distintos, unos llegando casi a 0 y otros casi a 20000, entonces tome la decision de tomar aquellos que consideré relevantes, siendo un total de 26 empresas de las 64 existentes
# esto porque la concentracion de datos se encuentra aqui, siendo una empresa la que se superpone a todas las demas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Muy buen trabajo con la gráfica! En efecto se observa que Flash Cab lidera en volumen de viajes, lo que sugiere una fuerte concentración del mercado. Esto puede estar relacionado con su cobertura, cantidad de vehículos o buenas estrategias comerciales.
#
# </div>

# %%
#grafico para los 10 barrios principales por número de finalizaciones
plt.figure(figsize=(10, 6))
plt.barh(diez_principales['dropoff_location_name'], diez_principales['average_trips'],color='lightgreen')
plt.gca().grid(True, alpha=0.5) 
plt.xlabel('Promedio de viajes')
plt.ylabel('Barrio')
plt.title('10 barrios mas populares por finalización de viajes')
plt.tight_layout()
plt.show()

# %% [markdown]
# conclusiones y resultados:
# aqui simplemente siguiendo las indicaciones se graficaron los 10 barrios con mas finalizaciones de viaje
# igual que en el a anterior podemos ver que siempre habra columnas que se diferencien sobre las otras, aqui aunque existen 4 con grandes cantidades sigue habiendo 2 que contiene mas datos, siendo la direncia entre una y la otra alrededor de 500

# %% [markdown]
# Conclusion final:
# la empresa de taxti mas usada es flash cab y el barrio de finilizacion mas popular fue loop seguido de river north

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Buen trabajo obteniendo el Top de barrios! Lograste identificar y jerarquizar bien los de mayor actividad, destacando la diferencia notable con barrios como Loop y River North, que seguramente destacan por su relevancia comercial y turística.
#
# </div>

# %%
#importar dataframe para hipotesis
df_7_sql = pd.read_csv('/datasets/project_sql_result_07.csv')
# start_ts: fecha y hora de la recogida
# weather_conditions: condiciones climáticas en el momento en el que comenzó el viaje
# duration_seconds: duración del viaje en segundos

# %%
#revisar los datos que contienen
df_7_sql.info()
print()
print(df_7_sql.sample(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   start_ts            1068 non-null   object
#  1   weather_conditions  1068 non-null   object
#  2   duration_seconds    1068 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 25.2+ KB
#
#                 start_ts weather_conditions  duration_seconds
# 922  2017-11-18 08:00:00                Bad            1495.0
# 717  2017-11-18 10:00:00                Bad            1560.0
# 371  2017-11-11 11:00:00               Good            1596.0
# 569  2017-11-18 15:00:00               Good            2889.0
# 781  2017-11-11 12:00:00               Good            1993.0

# %% [markdown]
# observaciones:
# este cuenta con 1068 filas, contiene 3 columnas, ninguna de estas columnas posee datos nulos, las segunda columna tiene bien el tipo de dato, podriamos pasar la primera columna a formato datatime,, y en la ultima verificar si es necesario el punto decinal o es posible cambiarlo a int

# %%
#estudiar los datos que contienen
# ver deciamles para duration_seconds
print("Ver valores")
print(df_7_sql['duration_seconds'].sample(10))

# verificar decimales
print((df_7_sql['duration_seconds'] % 1 != 0).sum())

# Redondear hacia arriba y convertir a entero
df_7_sql['duration_seconds'] = np.ceil(df_7_sql['duration_seconds']).astype(int)

print("Ver valores nuevamente")
print(df_7_sql['duration_seconds'].sample(10))
# Out:
# Ver valores
# 597    1282.0
# 519    1878.0
# 794    1380.0
# 960    1486.0
# 665    1620.0
# 38     1477.0
# 679    2400.0
# 791    1260.0
# 899    3480.0
# 203     480.0
# Name: duration_seconds, dtype: float64
# 0
# Ver valores nuevamente
# 1032    1908
# 966     2132
# 919     1519
# 523     1260
# 691     2880
# 417     2286
# 393     2982
# 368     1354
# 671     2256
# 709     2963
# Name: duration_seconds, dtype: int64

# %%
#cambiar de object a datatime
df_7_sql['start_ts'] = pd.to_datetime(df_7_sql['start_ts'])

df_7_sql['dia_semana'] = df_7_sql['start_ts'].dt.weekday
df_7_sql['sabado'] = df_7_sql['start_ts'].dt.weekday == 5

df_7_sql['hora'] = df_7_sql['start_ts'].dt.hour
df_7_sql['fecha'] = df_7_sql['start_ts'].dt.date

df_7_sql.info()
print(df_7_sql.sample(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   start_ts            1068 non-null   datetime64[ns]
#  1   weather_conditions  1068 non-null   object
#  2   duration_seconds    1068 non-null   int64
#  3   dia_semana          1068 non-null   int64
#  4   sabado              1068 non-null   bool
#  5   hora                1068 non-null   int64
#  6   fecha               1068 non-null   object
# dtypes: bool(1), datetime64[ns](1), int64(3), object(2)
# memory usage: 51.2+ KB
#                start_ts weather_conditions  duration_seconds  dia_semana  \
# 210 2017-11-11 20:00:00               Good              1500           5
# 632 2017-11-11 10:00:00               Good              1412           5
# 970 2017-11-25 13:00:00               Good              1800           5
# ...

# %% [markdown]
# pequeño recordatorio: /datasets/project_sql_result_07.csv contiene datos sobre viajes desde el Loop hasta el Aeropuerto Internacional O'Hare.

# %%
#declaracion de alpha
alpha = .05

#verificar dia de la semana, todos son sabados
print(df_7_sql['dia_semana'].unique())

# Filtrar sábados lluviosos
sabados_lluviosos = df_7_sql[
    (df_7_sql['weather_conditions'] == 'Bad')
]

# filtrar dias normales
sabados_normales = df_7_sql[
      (df_7_sql['weather_conditions'] == 'Good')
]
print(sabados_lluviosos.head())
print('-'*30)
print(sabados_normales.head())
# Out:
# [5]
#               start_ts weather_conditions  duration_seconds  dia_semana  \
# 6  2017-11-04 16:00:00                Bad              2969           5
# 30 2017-11-18 12:00:00                Bad              1980           5
# 34 2017-11-04 17:00:00                Bad              2460           5
# 51 2017-11-04 16:00:00                Bad              2760           5
# 52 2017-11-18 12:00:00                Bad              2460           5
#
#     sabado  hora       fecha
# 6     True    16  2017-11-04
# 30    True    12  2017-11-18
# 34    True    17  2017-11-04
# 51    True    16  2017-11-04
# 52    True    12  2017-11-18
# ------------------------------
#              start_ts weather_conditions  duration_seconds  dia_semana  \
# 0 2017-11-25 16:00:00               Good              2410           5
# 1 2017-11-25 14:00:00               Good              1920           5
# 2 2017-11-25 12:00:00               Good              1543           5
# ...

# %% [markdown]
# h0:"La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare no cambia los sábados lluviosos"
# h1:"La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare cambia los sábados lluviosos"

# %%
results = st.ttest_ind(sabados_lluviosos['duration_seconds'], sabados_normales['duration_seconds']) # si el valor p es menor que alpha, rechazamos la hipótesis
print('valor p: ', results.pvalue) 
if results.pvalue < alpha: # comparar el valor p con el umbral
    print("Rechazamos la hipótesis nula")
    print("La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare cambia los sábados lluviosos")
else:
    print("No podemos rechazar la hipótesis nula")
    print("La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare no cambia los sábados lluviosos")
# Out:
# valor p:  6.517970327099473e-12
# Rechazamos la hipótesis nula
# La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare cambia los sábados lluviosos

# %%
# Compararemos ambos dias
print("sabados lluviosos")
print(f"Cantidad de viajes: {len(sabados_lluviosos)}")
print(f"Duración promedio: {sabados_lluviosos['duration_seconds'].mean():.2f}")
print(f"Desviación estándar: {sabados_lluviosos['duration_seconds'].std():.2f}")
print(f"Mediana: {sabados_lluviosos['duration_seconds'].median()}")
print()
print("sabados normales")
print(f"Cantidad de viajes: {len(sabados_normales)}")
print(f"Duración promedio: {sabados_normales['duration_seconds'].mean():.2f}")
print(f"Desviación estándar: {sabados_normales['duration_seconds'].std():.2f}")
print(f"Mediana: {sabados_normales['duration_seconds'].median()}")
print()
print(df_7_sql['weather_conditions'].value_counts())
print(f"Porcentaje de días lluviosos: {len(sabados_lluviosos)/len(df_7_sql)*100:.2f}%")
# Out:
# sabados lluviosos
# Cantidad de viajes: 180
# Duración promedio: 2427.21
# Desviación estándar: 721.31
# Mediana: 2540.0
#
# sabados normales
# Cantidad de viajes: 888
# Duración promedio: 1999.68
# Desviación estándar: 759.20
# Mediana: 1800.0
#
# Good    888
# Bad     180
# Name: weather_conditions, dtype: int64
# Porcentaje de días lluviosos: 16.85%

# %% [markdown]
# Revision de lo anterior:
# podemos ver que efectivamente hay un cambio en los promedios, de si es normal o nublado, siendo una diferencia bastante notable, podemos ver que los numeros crecen enormemente ya que la diferencia en la cantidad de viajes es abismal, y aun logran subir bastante el promedio, tambien hay diferencia en la desviacion estandar, y podemos confirmar todo esto tambien con la mediana ya que hay casi 700 segundos de diferencia.
# no olvidemos que solo el 16.8% de todas las filas pertenecen a dias lluviosos

# %% [markdown]
# Cómo planteé las hipótesis:
# use de referencia el mensaje indicadado "La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare cambia los sábados lluviosos"
#
# La hipótesis nula (H₀) siempre implica ausencia de diferencias.
# La hipótesis alternativa (H₁) contradice la nula, afirmando que SÍ hay diferencia entre los grupos.
#
# Por tanto:
# - H₀: No hay diferencias en los promedios de duración
# - H₁: Sí hay diferencias significativas en los promedios

# %% [markdown]
# use la hipótesis sobre la igualdad de las medias de dos poblaciones:
# ya que son 2 muestras diferentes y independientes, tengo una variable numerica continua que son los segundosm especificamente se me pedia comprar medias(promedios) y saber si estos cambian entre ambos grupos, mis muestras son lo suficientemente grandes para usar esto
#
# elegi 0.05 para el nivel de significancia ta qye este es el estandar usado en alasisis estadisticos, acepto un 5% de probailidad de error
# como mi valor p es extremadamente pequeño, entonces rechazo la hipotesis nula ya que hay suficiente evidencia estadistica para decir que los promedios si cambian de un dia lluvioso a uno normal

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Has desarrollado correctamente un análisis orientado a verificar una hipótesis sobre la duración de los viajes en diferentes condiciones climáticas durante los sábados. Has realizado una limpieza apropiada de los datos, incluyendo el redondeo y conversión de duración, y una adecuada transformación de fechas para crear nuevas variables útiles.
#
# </div>
# </div>
